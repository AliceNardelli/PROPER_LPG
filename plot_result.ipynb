# %%
#extro 0.4
#dis 0.3
#unsc 0.0

# %%
c_e=-0.4
d_e=5
dur=[0,7,10,7,5,10,5,10,5,10,5,10,5,10,5,10,5,10,5]

# %%
len(dur)
# Out:
# 19

# %% [markdown]
# 0.0002:   (PRESENT_ASSEMBLY_ROOM R1) [7.0000]
# 7.0007:   (APPROACHING_HUMAN) [5.0000]
# 12.0012:   (REACHING_PRODUCTION_ROOM R1 R2) [10.0000]
# 22.0015:   (PRESENT_PRODUCTION_ROOM R2) [7.0000]
# 29.0020:   (APPROACHING_HUMAN) [5.0000]
# 34.0025:   (ASK_PICK_THE_BLOCK R2) [5.0000]
#
#
# 39.0030:   (REACHING_ASSEMBLY_ROOM R2 R1) [10.0000]
#
# 49.0035:   (EXPRESS_ENTHUSIASM) [5.0000]
#
#
# 54.0040:   (ASK_ASSEMBLY_BLOCK R1) [5.0000]
# 59.0045:   (APPROACHING_HUMAN) [5.0000]
#
#
# 64.0050:   (REACHING_PRODUCTION_ROOM R1 R2) [10.0000]
# 74.0053:   (ASK_PICK_THE_BLOCK R2) [5.0000]
#
# 79.0058:   (APPROACHING_HUMAN) [5.0000]
#
# 84.0063:   (REACHING_ASSEMBLY_ROOM R2 R1) [10.0000]
# 94.0068:   (APPROACHING_HUMAN) [5.0000]
# 99.0073:   (ASK_ASSEMBLY_BLOCK R1) [5.0000]
# 109.0083:   (REACHING_PRODUCTION_ROOM R1 R2) [10.0000]
#
#
# 119.0088:   (APPROACHING_HUMAN) [5.0000]
#
# 124.0093:   (ASK_PICK_THE_BLOCK R2) [5.0000]
#
#
# 129.0098:   (REACHING_ASSEMBLY_ROOM R2 R1) [10.0000]
#
#
# 139.0103:   (APPROACHING_HUMAN) [5.0000]
#
#
# 144.0108:   (ASK_ASSEMBLY_BLOCK R1) [5.0000]
# 149.0112:   (REACHING_PRODUCTION_ROOM R1 R2) [10.0000]
#
#
# 159.0117:   (CHIT_CHAT) [5.0000]
# 164.0122:   (ASK_PICK_THE_BLOCK R2) [5.0000]
#
# 169.0127:   (CHIT_CHAT) [5.0000]
#
# 174.0132:   (REACHING_ASSEMBLY_ROOM R2 R1) [10.0000]
# 189.0142:   (ASK_ASSEMBLY_BLOCK R1) [5.0000]
# 194.0147:   (CHECK_FINISHED R1) [0.0000]

# %%
l_e=[7,4.2,9.2,5.2,2.4,7.4,5.4,1.4,6.4,4.4,9.4,5.4,3.4,8.4,4.4,9.4,7.4,3.4,8.4,6.4,2.4,7.4,5.4,1.4,6.4,4.4,9.4,5.4,3.4]

# %%
time_e=len(l_e)*[0]
c=0
for i in range(len(l_e)):
   if i!=0:
     if l_e[i]>l_e[i-1]:
        time_e[i]=time_e[i-1]
     else:
        c+=1
        time_e[i]=time_e[i-1]+dur[c]

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
d_e=pd.DataFrame(columns=["time","level"])

# %%
d_e["time"]=np.array(time_e)
d_e["level"]=np.array(l_e)

# %%
d_e
# Out:
#      time  level
# 0     0.0    7.0
# 1     7.0    4.2
# 2     7.1    9.2
# 3    17.1    5.2
# 4    24.1    2.4
# 5    24.2    7.4
# 6    29.2    5.4
# 7    39.2    1.4
# 8    39.3    6.4
# 9    44.3    4.4
# 10   44.4    9.4
# 11   54.4    5.4
# 12   59.4    3.4
# 13   59.5    8.4
# 14   69.5    4.4
# 15   69.6    9.4
# 16   74.6    7.4
# 17   84.6    3.4
# 18   84.7    8.4
# 19   89.7    6.4
# 20   99.7    2.4
# 21   99.8    7.4
# 22  104.8    5.4
# 23  114.8    1.4
# 24  114.9    6.4
# 25  119.9    4.4
# 26  120.0    9.4
# 27  130.0    5.4
# 28  135.0    3.4

# %%
sns.scatterplot(data=d_e, x="time", y="level")

# %%
import matplotlib.pyplot as plt
plt.scatter(d_e.time,d_e.level)
plt.plot(d_e.time,d_e.level)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[65], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.scatter(d_e.time,d_e.level)
# ----> 3 plt.plot(d_e.time,d_e.level)
#       4 plt.show()
#
# File /usr/lib/python3/dist-packages/matplotlib/pyplot.py:2787, in plot(scalex, scaley, data, *args, **kwargs)
#    2785 @docstring.copy(Axes.plot)
#    2786 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2787     return gca().plot(
#    2788         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2789         is not None else {}), **kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_axes.py:1665, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1434 """
#    1435 Plot y versus x as lines and/or markers.
#    1436
#    (...)
#    1662 (``'green'``) or hex strings (``'#008000'``).
#    1663 """
#    1664 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666 for line in lines:
#    1667     self.add_line(line)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:225, in _process_plot_var_args.__call__(self, *args, **kwargs)
#     223     this += args[0],
#     224     args = args[1:]
# --> 225 yield from self._plot_args(this, kwargs)
#
# File /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:386, in _process_plot_var_args._plot_args(self, tup, kwargs)
#     383         kw[k] = v
#     385 if len(tup) == 2:
# --> 386     x = _check_1d(tup[0])
#     387     y = _check_1d(tup[-1])
#     388 else:
#
# File /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402, in _check_1d(x)
#    1400 else:
#    1401     try:
# -> 1402         ndim = x[:, None].ndim
#    1403         # work around https://github.com/pandas-dev/pandas/issues/27775
#    1404         # which mean the shape is not as expected. That this ever worked
#    1405         # was an unintentional quirk of pandas the above line will raise
#    1406         # an exception in the future.
#    1407         if ndim < 2:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1038, in Series.__getitem__(self, key)
#    1035     key = np.asarray(key, dtype=bool)
#    1036     return self._get_values(key)
# -> 1038 return self._get_with(key)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1053, in Series._get_with(self, key)
#    1048     raise TypeError(
#    1049         "Indexing a Series with DataFrame is not "
#    1050         "supported, use the appropriate DataFrame column"
#    1051     )
#    1052 elif isinstance(key, tuple):
# -> 1053     return self._get_values_tuple(key)
#    1055 elif not is_list_like(key):
#    1056     # e.g. scalars that aren't recognized by lib.is_scalar, GH#32684
#    1057     return self.loc[key]
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/series.py:1087, in Series._get_values_tuple(self, key)
#    1082 if com.any_none(*key):
#    1083     # mpl compat if we look up e.g. ser[:, np.newaxis];
#    1084     #  see tests.series.timeseries.test_mpl_compat_hack
#    1085     # the asarray is needed to avoid returning a 2D DatetimeArray
#    1086     result = np.asarray(self._values[key])
# -> 1087     disallow_ndim_indexing(result)
#    1088     return result
#    1090 if not isinstance(self.index, MultiIndex):
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexers/utils.py:343, in disallow_ndim_indexing(result)
#     335 """
#     336 Helper function to disallow multi-dimensional indexing on 1D Series/Index.
#     337
#    (...)
#     340 in GH#30588.
#     341 """
#     342 if np.ndim(result) > 1:
# --> 343     raise ValueError(
#     344         "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     345         "supported. Convert to a numpy array before indexing instead."
#     346     )
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
d_e
# Out:
#     time  level
# 0      0    7.0
# 1      7    4.2
# 2      7    9.2
# 3     17    5.2
# 4     24    2.4
# 5     24    7.4
# 6     29    5.4
# 7     39    1.4
# 8     39    6.4
# 9     44    4.4
# 10    44    9.4
# 11    54    5.4
# 12    59    3.4
# 13    59    8.4
# 14    69    4.4
# 15    69    9.4
# 16    74    7.4
# 17    84    3.4
# 18    84    8.4
# 19    89    6.4
# 20    99    2.4
# 21    99    7.4
# 22   104    5.4
# 23   114    1.4
# 24   114    6.4
# 25   119    4.4
# 26   119    9.4
# 27   129    5.4
# 28   134    3.4
